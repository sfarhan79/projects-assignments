# %%
# !pip install keras
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import normalize

# %%
gas=pd.read_csv("https://raw.githubusercontent.com/sfarhan79/datasets/main/python%20datasets/csv/gas%20turbines.csv")
gas.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
gas.shape
# Out:
# (15039, 11)

# %%
gas.T
# Out:
#           0          1          2          3          4          5      \
# AT       6.8594     6.7850     6.8977     7.0569     7.3978     7.6998
# AP    1007.9000  1008.4000  1008.8000  1009.2000  1009.7000  1010.7000
# AH      96.7990    97.1180    95.9390    95.2490    95.1500    92.7080
# AFDP     3.5000     3.4998     3.4824     3.4805     3.4976     3.5236
# GTEP    19.6630    19.7280    19.7790    19.7920    19.7650    19.6830
# TIT   1059.2000  1059.3000  1059.4000  1059.6000  1059.7000  1059.8000
# TAT    550.0000   550.0000   549.8700   549.9900   549.9800   549.9700
# TEY    114.7000   114.7200   114.7100   114.7200   114.7200   114.7200
# CDP     10.6050    10.5980    10.6010    10.6060    10.6120    10.6260
# CO       3.1547     3.2363     3.2012     3.1923     3.2484     3.4467
# NOX     82.7220    82.7760    82.4680    82.6700    82.3110    82.4090
#
#           6          7          8          9      ...      15029      15030  \
# ...

# %%
sns.set_style("darkgrid")
sns.pairplot(gas)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
corr=gas.corr()
f,ax=plt.subplots(figsize=(12,10))
sns.heatmap(corr,vmax=.8,square=True,annot=True)
# Out:
# <Axes: >

# %%
gas2=X.copy()

correlations = gas2.corrwith(gas["TEY"])
correlations = correlations[correlations!=1]
positive_correlations = correlations[correlations >0].sort_values(ascending = False)
negative_correlations =correlations[correlations<0].sort_values(ascending = False)

correlations.plot.bar(
        figsize = (12, 8),
        fontsize = 15,
        color = 'b',
        rot = 90, grid = True)
plt.title('Correlation with Turbine energy yield \n',
horizontalalignment="center", fontstyle = "normal",
fontsize = "22", fontfamily = "sans-serif")
# Out:
# Text(0.5, 1.0, 'Correlation with Turbine energy yield \n')

# %%
X=gas.iloc[:,0:10]
Y=gas.iloc[:,10]

# %%
model=Sequential()
model.add(Dense(12,input_dim=10,activation="relu"))
model.add(Dense(10,activation="relu"))
model.add(Dense(10,activation="relu"))
model.add(Dense(1,activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 12)                132
#
#  dense_13 (Dense)            (None, 10)                130
#
#  dense_14 (Dense)            (None, 10)                110
#
#  dense_15 (Dense)            (None, 1)                 11
#
# ...
# Total params: 383 (1.50 KB)
# Trainable params: 383 (1.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
hist=model.fit(x_norm,Y,epochs=100,validation_split=0.33,batch_size=10)
# Out:
# Epoch 1/100
# 1008/1008 [==============================] - 4s 3ms/step - loss: -13648.0254 - accuracy: 0.0000e+00 - val_loss: -61287.4531 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 1008/1008 [==============================] - 3s 3ms/step - loss: -335519.1875 - accuracy: 0.0000e+00 - val_loss: -743083.1250 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1782634.7500 - accuracy: 0.0000e+00 - val_loss: -2911655.5000 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 1008/1008 [==============================] - 3s 2ms/step - loss: -5264577.5000 - accuracy: 0.0000e+00 - val_loss: -7391249.0000 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 1008/1008 [==============================] - 2s 2ms/step - loss: -11640788.0000 - accuracy: 0.0000e+00 - val_loss: -14976757.0000 - val_accuracy: 0.0000e+00
# Epoch 6/100
# ...

# %%
score=model.evaluate(X,Y)
print(model.metrics_names)
# Out:
# 470/470 [==============================] - 1s 1ms/step - loss: -370403381870592.0000 - accuracy: 0.0000e+00
# ['loss', 'accuracy']

# %%
print("%s: %.2f%%" %(model.metrics_names[1],score[1]*100))
print(score)
# Out:
# accuracy: 0.00%
# [-370403381870592.0, 0.0]

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#Visualizing Accuracy and Loss
#Summarizing Accuracy
plt.plot(hist.history["accuracy"])
plt.plot(hist.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

#Summarizing Loss
plt.plot(hist.history["loss"])
plt.plot(hist.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
